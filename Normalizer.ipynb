# %%
from lenskit.metrics import dataGenerator
from lenskit import batch, topn, util, topnFair
from lenskit import crossfold as xf
from lenskit.algorithms import Recommender, als, item_knn as knn
from lenskit import topn, topnFair
from lenskit.topnFair import *

import numpy as np
import pandas as pd

# %%
normalizer = calculateNormalizer(11,9,"rND")
# Out:
# calculating normalizer with userN= 11 , proN 9 , measure rND
# calculateNDFairnessPara
# user_n =  11
# pro_n =  9
# protectedgroup
# [0, 1, 2, 3, 4, 5, 6, 7, 8]
# calculateNDFairnessPara
# user_n =  11
# pro_n =  9
# protectedgroup
# [0, 1, 2, 3, 4, 5, 6, 7, 8]
# calculateNDFairnessPara
# user_n =  11
# pro_n =  9
# protectedgroup
# [0, 1, 2, 3, 4, 5, 6, 7, 8]
# calculateNDFairnessPara
# user_n =  11
# pro_n =  9
# protectedgroup
# [0, 1, 2, 3, 4, 5, 6, 7, 8]
# calculateNDFairnessPara
# user_n =  11
# pro_n =  9
# protectedgroup
# [0, 1, 2, 3, 4, 5, 6, 7, 8]
# calculateNDFairnessPara
# user_n =  11
# pro_n =  9
# protectedgroup
# [0, 1, 2, 3, 4, 5, 6, 7, 8]
# calculateNDFairnessPara
# user_n =  11
# pro_n =  9
# protectedgroup
# [0, 1, 2, 3, 4, 5, 6, 7, 8]
# calculateNDFairnessPara
# user_n =  11
# pro_n =  9
# protectedgroup
# [0, 1, 2, 3, 4, 5, 6, 7, 8]
# calculateNDFairnessPara
# user_n =  11
# pro_n =  9
# protectedgroup
# [0, 1, 2, 3, 4, 5, 6, 7, 8]
# calculateNDFairnessPara
# user_n =  11
# pro_n =  9
# protectedgroup
# [0, 1, 2, 3, 4, 5, 6, 7, 8]
# calculateNDFairnessPara
# user_n =  11
# pro_n =  9
# protectedgroup
# [0, 1, 2, 3, 4, 5, 6, 7, 8]
# calculateNDFairnessPara
# user_n =  11
# pro_n =  9
# protectedgroup
# [0, 1, 2, 3, 4, 5, 6, 7, 8]
# calculateNDFairnessPara
# user_n =  11
# pro_n =  9
# protectedgroup
# [0, 1, 2, 3, 4, 5, 6, 7, 8]
# calculateNDFairnessPara
# user_n =  11
# pro_n =  9
# protectedgroup
# [0, 1, 2, 3, 4, 5, 6, 7, 8]
# calculateNDFairnessPara
# user_n =  11
# pro_n =  9
# protectedgroup
# [0, 1, 2, 3, 4, 5, 6, 7, 8]
# calculateNDFairnessPara
# user_n =  11
# pro_n =  9
# protectedgroup
# [0, 1, 2, 3, 4, 5, 6, 7, 8]
# calculateNDFairnessPara
# user_n =  11
# pro_n =  9
# protectedgroup
# [0, 1, 2, 3, 4, 5, 6, 7, 8]
# calculateNDFairnessPara
# user_n =  11
# pro_n =  9
# protectedgroup
# [0, 1, 2, 3, 4, 5, 6, 7, 8]
# calculateNDFairnessPara
# user_n =  11
# pro_n =  9
# protectedgroup
# [0, 1, 2, 3, 4, 5, 6, 7, 8]
# calculateNDFairnessPara
# user_n =  11
# pro_n =  9
# protectedgroup
# [0, 1, 2, 3, 4, 5, 6, 7, 8]
# normalizer value to return :  0.021811255076713346
